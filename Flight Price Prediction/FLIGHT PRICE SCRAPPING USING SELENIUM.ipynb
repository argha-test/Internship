# %%
#import all necesary libraries
import pandas as pd
import numpy as np
import selenium
from selenium import webdriver
from selenium.webdriver.common.action_chains import ActionChains
from selenium.common.exceptions import StaleElementReferenceException, NoSuchElementException
import warnings
warnings.filterwarnings("ignore")

# %%
#load webdriver and get the website
driver=webdriver.Chrome(r"D:\chromedriver\chromedriver.exe")
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=CCU&originCountry=IN&destination=BOM&destinationCountry=IN&flight_depart_date=01%2F04%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1181331668869"
driver.get(url)

# %%
airline1=[]
source1=[]
destination1=[]
price1=[]
stops1=[]
route1=[]
Dep_time1=[]
arr_time1=[]
date1=[]
duration1=[]
add_info1=[]

try:
    for i in driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span"):
        airline1.append(i.text)
except NoSuchElementexception:
    airline1.append("--")
except StaleElementReferenceException:
    airline1.append("--")
except:
    airline1.append("--")
try:
    for j in driver.find_elements_by_xpath("//div[@class='i-b pr']"):
        Dep_time1.append(j.text)
except NoSuchElementException:
    Dep_time1.append("--")
except StaleElementReferenceException:
    Dep_time1.append("--")
except:
    Dep_time1.append("--")
try:
    for k in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[1]"):
        arr_time1.append(k.text)
except NoSuchElementException:
    arr_time1.append("--")
except StaleElementReferenceException:
    arr_time1.append("--")
except:
    arr_time1.append("--")
try:
    for l in driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/p"):
        duration1.append(l.text)
except NoSuchElementException:
    duration1.append("--")
except StaleElementReferenceException:
    duration1.append("--")
except:
    duration1.append("--")
try:
    for m in driver.find_elements_by_xpath("//div[@class='pr i-b mr-2']/div[2]"):
        price1.append(m.text)
except NoSuchElementException:
    price1.append("--")
except StaleElementReferenceException:
    price1.append("--")
except:
    price1.append("--")
try:
    for n in driver.find_elements_by_xpath("//div/div[1]/div[2]/div/div/div/div/div[1]/div/div[1]/p"):
        source1.append(n.text)
except NoSuchElementException:
    source1.append("--")
except StaleElementReferenceException:
    source1.append("--")
except:
    source1.append("--")
try:
    for o in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]"):
        destination1.append(o.text)
except NoSuchElementException:
    destination1.append("--")
except StaleElementReferenceException:
    destination1.append("--")
except:
    destination1.append("--")
try:
    for p in driver.find_elements_by_xpath("//span[@class='cursor-default']|//span[@class='dotted-borderbtm']"):
        stops1.append(p.text)
except NoSuchElementException:
    stops1.append("--")
except StaleElementReferenceException:
     stops1.append("--")
except:
     stops1.append("--")

    
for r in driver.find_elements_by_xpath("//div[@class='bold fs-12 mb-5']"):
    date1.append(r.text)

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=CCU&originCountry=IN&destination=BLR&destinationCountry=IN&flight_depart_date=02%2F04%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=831104779435'
driver.get(url)

# %%
driver.execute_script("window.scrollTo(0,document.body.scrollHeight)")

# %%
airline2=[]
source2=[]
destination2=[]
price2=[]
stops2=[]
route2=[]
Dep_time2=[]
arr_time2=[]
date2=[]
duration2=[]


try:
    for i in driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span"):
        airline2.append(i.text)
except NoSuchElementexception:
    airline2.append("--")
except StaleElementReferenceException:
    airline2.append("--")
except:
    airline2.append("--")
try:
    for j in driver.find_elements_by_xpath("//div[@class='i-b pr']"):
        Dep_time2.append(j.text)
except NoSuchElementException:
    Dep_time2.append("--")
except StaleElementReferenceException:
    Dep_time2.append("--")
except:
    Dep_time2.append("--")
try:
    for k in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[1]"):
        arr_time2.append(k.text)
except NoSuchElementException:
    arr_time2.append("--")
except StaleElementReferenceException:
    arr_time2.append("--")
except:
    arr_time2.append("--")
try:
    for l in driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/p"):
        duration2.append(l.text)
except NoSuchElementException:
    duration2.append("--")
except StaleElementReferenceException:
    duration2.append("--")
except:
    duration2.append("--")
try:
    for m in driver.find_elements_by_xpath("//div[@class='pr i-b mr-2']/div[2]"):
        price2.append(m.text)
except NoSuchElementException:
    price2.append("--")
except StaleElementReferenceException:
    price2.append("--")
except:
    price2.append("--")
try:
    for n in driver.find_elements_by_xpath("//div/div[1]/div[2]/div/div/div/div/div[1]/div/div[1]/p"):
        source2.append(n.text)
except NoSuchElementException:
    source2.append("--")
except StaleElementReferenceException:
    source2.append("--")
except:
    source2.append("--")
try:
    for o in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]"):
        destination2.append(o.text)
except NoSuchElementException:
    destination2.append("--")
except StaleElementReferenceException:
    destination2.append("--")
except:
    destination2.append("--")
try:
    for p in driver.find_elements_by_xpath("//span[@class='cursor-default']|//span[@class='dotted-borderbtm']"):
        stops2.append(p.text)
except NoSuchElementException:
    stops2.append("--")
except StaleElementReferenceException:
     stops2.append("--")
except:
     stops2.append("--")

    
for r in driver.find_elements_by_xpath("//div[@class='bold fs-12 mb-5']"):
    date2.append(r.text)

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=DEL&destinationCountry=IN&flexi=0&flight_depart_date=03%2F04%2F2022&hb=0&noOfSegments=1&origin=CCU&originCountry=IN&type=O&unique=692548932886&version=1.1&viewName=normal'
driver.get(url)

# %%
airline3=[]
source3=[]
destination3=[]
price3=[]
stops3=[]
route3=[]
Dep_time3=[]
arr_time3=[]
date3=[]
duration3=[]


try:
    for i in driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span"):
        airline3.append(i.text)
except NoSuchElementexception:
    airline3.append("--")
except StaleElementReferenceException:
    airline3.append("--")
except:
    airline3.append("--")
try:
    for j in driver.find_elements_by_xpath("//div[@class='i-b pr']"):
        Dep_time3.append(j.text)
except NoSuchElementException:
    Dep_time3.append("--")
except StaleElementReferenceException:
    Dep_time3.append("--")
except:
    Dep_time3.append("--")
try:
    for k in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[1]"):
        arr_time3.append(k.text)
except NoSuchElementException:
    arr_time3.append("--")
except StaleElementReferenceException:
    arr_time3.append("--")
except:
    arr_time3.append("--")
try:
    for l in driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/p"):
        duration3.append(l.text)
except NoSuchElementException:
    duration3.append("--")
except StaleElementReferenceException:
    duration3.append("--")
except:
    duration3.append("--")
try:
    for m in driver.find_elements_by_xpath("//div[@class='pr i-b mr-2']/div[2]"):
        price3.append(m.text)
except NoSuchElementException:
    price3.append("--")
except StaleElementReferenceException:
    price3.append("--")
except:
    price3.append("--")
try:
    for n in driver.find_elements_by_xpath("//div/div[1]/div[2]/div/div/div/div/div[1]/div/div[1]/p"):
        source3.append(n.text)
except NoSuchElementException:
    source3.append("--")
except StaleElementReferenceException:
    source3.append("--")
except:
    source3.append("--")
try:
    for o in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]"):
        destination3.append(o.text)
except NoSuchElementException:
    destination3.append("--")
except StaleElementReferenceException:
    destination3.append("--")
except:
    destination3.append("--")
try:
    for p in driver.find_elements_by_xpath("//span[@class='cursor-default']|//span[@class='dotted-borderbtm']"):
        stops3.append(p.text)
except NoSuchElementException:
    stops3.append("--")
except StaleElementReferenceException:
     stops3.append("--")
except:
     stops3.append("--")

    
for r in driver.find_elements_by_xpath("//div[@class='bold fs-12 mb-5']"):
    date3.append(r.text)

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=GOI&destinationCountry=IN&flexi=0&flight_depart_date=04%2F04%2F2022&hb=0&noOfSegments=1&origin=CCU&originCountry=IN&type=O&unique=1287661209117&version=1.1&viewName=normal'
driver.get(url)

# %%
airline4=[]
source4=[]
destination4=[]
price4=[]
stops4=[]
route4=[]
Dep_time4=[]
arr_time4=[]
date4=[]
duration4=[]


try:
    for i in driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span"):
        airline4.append(i.text)
except NoSuchElementexception:
    airline4.append("--")
except StaleElementReferenceException:
    airline4.append("--")
except:
    airline4.append("--")
try:
    for j in driver.find_elements_by_xpath("//div[@class='i-b pr']"):
        Dep_time4.append(j.text)
except NoSuchElementException:
    Dep_time4.append("--")
except StaleElementReferenceException:
    Dep_time4.append("--")
except:
    Dep_time4.append("--")
try:
    for k in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[1]"):
        arr_time4.append(k.text)
except NoSuchElementException:
    arr_time4.append("--")
except StaleElementReferenceException:
    arr_time4.append("--")
except:
    arr_time4.append("--")
try:
    for l in driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/p"):
        duration4.append(l.text)
except NoSuchElementException:
    duration4.append("--")
except StaleElementReferenceException:
    duration4.append("--")
except:
    duration4.append("--")
try:
    for m in driver.find_elements_by_xpath("//div[@class='pr i-b mr-2']/div[2]"):
        price4.append(m.text)
except NoSuchElementException:
    price4.append("--")
except StaleElementReferenceException:
    price4.append("--")
except:
    price4.append("--")
try:
    for n in driver.find_elements_by_xpath("//div/div[1]/div[2]/div/div/div/div/div[1]/div/div[1]/p"):
        source4.append(n.text)
except NoSuchElementException:
    source4.append("--")
except StaleElementReferenceException:
    source4.append("--")
except:
    source4.append("--")
try:
    for o in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]"):
        destination4.append(o.text)
except NoSuchElementException:
    destination4.append("--")
except StaleElementReferenceException:
    destination4.append("--")
except:
    destination4.append("--")
try:
    for p in driver.find_elements_by_xpath("//span[@class='cursor-default']|//span[@class='dotted-borderbtm']"):
        stops4.append(p.text)
except NoSuchElementException:
    stops4.append("--")
except StaleElementReferenceException:
     stops4.append("--")
except:
     stops4.append("--")

    
for r in driver.find_elements_by_xpath("//div[@class='bold fs-12 mb-5']"):
    date4.append(r.text)

# %%
len(source1+source2+source3+source4)
# Out:
# 481

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=01%2F04%2F2022&hb=0&noOfSegments=1&origin=GOI&originCountry=IN&type=O&unique=1565525808644&version=1.1&viewName=normal'
driver.get(url)

# %%
airline5=[]
source5=[]
destination5=[]
price5=[]
stops5=[]
route5=[]
Dep_time5=[]
arr_time5=[]
date5=[]
duration5=[]


try:
    for i in driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span"):
        airline5.append(i.text)
except NoSuchElementexception:
    airline5.append("--")
except StaleElementReferenceException:
    airline5.append("--")
except:
    airline5.append("--")
try:
    for j in driver.find_elements_by_xpath("//div[@class='i-b pr']"):
        Dep_time5.append(j.text)
except NoSuchElementException:
    Dep_time5.append("--")
except StaleElementReferenceException:
    Dep_time5.append("--")
except:
    Dep_time5.append("--")
try:
    for k in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[1]"):
        arr_time5.append(k.text)
except NoSuchElementException:
    arr_time5.append("--")
except StaleElementReferenceException:
    arr_time5.append("--")
except:
    arr_time5.append("--")
try:
    for l in driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/p"):
        duration5.append(l.text)
except NoSuchElementException:
    duration5.append("--")
except StaleElementReferenceException:
    duration5.append("--")
except:
    duration5.append("--")
try:
    for m in driver.find_elements_by_xpath("//div[@class='pr i-b mr-2']/div[2]"):
        price5.append(m.text)
except NoSuchElementException:
    price5.append("--")
except StaleElementReferenceException:
    price5.append("--")
except:
    price5.append("--")
try:
    for n in driver.find_elements_by_xpath("//div/div[1]/div[2]/div/div/div/div/div[1]/div/div[1]/p"):
        source5.append(n.text)
except NoSuchElementException:
    source5.append("--")
except StaleElementReferenceException:
    source5.append("--")
except:
    source5.append("--")
try:
    for o in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]"):
        destination5.append(o.text)
except NoSuchElementException:
    destination5.append("--")
except StaleElementReferenceException:
    destination5.append("--")
except:
    destination5.append("--")
try:
    for p in driver.find_elements_by_xpath("//span[@class='cursor-default']|//span[@class='dotted-borderbtm']"):
        stops5.append(p.text)
except NoSuchElementException:
    stops5.append("--")
except StaleElementReferenceException:
     stops5.append("--")
except:
     stops5.append("--")

    
for r in driver.find_elements_by_xpath("//div[@class='bold fs-12 mb-5']"):
    date5.append(r.text)

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=04%2F04%2F2022&hb=0&noOfSegments=1&origin=DEL&originCountry=IN&type=O&unique=400463110687&version=1.1&viewName=normal'
driver.get(url)

# %%
airline6=[]
source6=[]
destination6=[]
price6=[]
stops6=[]
Dep_time6=[]
arr_time6=[]
date6=[]
duration6=[]


try:
    for i in driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span"):
        airline6.append(i.text)
except NoSuchElementexception:
    airline6.append("--")
except StaleElementReferenceException:
    airline6.append("--")
except:
    airline6.append("--")
try:
    for j in driver.find_elements_by_xpath("//div[@class='i-b pr']"):
        Dep_time6.append(j.text)
except NoSuchElementException:
    Dep_time6.append("--")
except StaleElementReferenceException:
    Dep_time6.append("--")
except:
    Dep_time6.append("--")
try:
    for k in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[1]"):
        arr_time6.append(k.text)
except NoSuchElementException:
    arr_time6.append("--")
except StaleElementReferenceException:
    arr_time6.append("--")
except:
    arr_time6.append("--")
try:
    for l in driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/p"):
        duration6.append(l.text)
except NoSuchElementException:
    duration6.append("--")
except StaleElementReferenceException:
    duration6.append("--")
except:
    duration6.append("--")
try:
    for m in driver.find_elements_by_xpath("//div[@class='pr i-b mr-2']/div[2]"):
        price6.append(m.text)
except NoSuchElementException:
    price6.append("--")
except StaleElementReferenceException:
    price6.append("--")
except:
    price6.append("--")
try:
    for n in driver.find_elements_by_xpath("//div/div[1]/div[2]/div/div/div/div/div[1]/div/div[1]/p"):
        source6.append(n.text)
except NoSuchElementException:
    source6.append("--")
except StaleElementReferenceException:
    source6.append("--")
except:
    source6.append("--")
try:
    for o in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]"):
        destination6.append(o.text)
except NoSuchElementException:
    destination6.append("--")
except StaleElementReferenceException:
    destination6.append("--")
except:
    destination6.append("--")
try:
    for p in driver.find_elements_by_xpath("//span[@class='cursor-default']|//span[@class='dotted-borderbtm']"):
        stops6.append(p.text)
except NoSuchElementException:
    stops6.append("--")
except StaleElementReferenceException:
     stops6.append("--")
except:
     stops6.append("--")

    
for r in driver.find_elements_by_xpath("//div[@class='bold fs-12 mb-5']"):
    date6.append(r.text)

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=BOM&originCountry=IN&destination=CCU&destinationCountry=IN&flight_depart_date=03%2F04%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1638418320015'
driver.get(url)

# %%
airline7=[]
source7=[]
destination7=[]
price7=[]
stops7=[]
Dep_time7=[]
arr_time7=[]
date7=[]
duration7=[]


try:
    for i in driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span"):
        airline7.append(i.text)
except NoSuchElementexception:
    airline7.append("--")
except StaleElementReferenceException:
    airline7.append("--")
except:
    airline7.append("--")
try:
    for j in driver.find_elements_by_xpath("//div[@class='i-b pr']"):
        Dep_time7.append(j.text)
except NoSuchElementException:
    Dep_time7.append("--")
except StaleElementReferenceException:
    Dep_time7.append("--")
except:
    Dep_time7.append("--")
try:
    for k in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[1]"):
        arr_time7.append(k.text)
except NoSuchElementException:
    arr_time7.append("--")
except StaleElementReferenceException:
    arr_time7.append("--")
except:
    arr_time7.append("--")
try:
    for l in driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/p"):
        duration7.append(l.text)
except NoSuchElementException:
    duration7.append("--")
except StaleElementReferenceException:
    duration7.append("--")
except:
    duration7.append("--")
try:
    for m in driver.find_elements_by_xpath("//div[@class='pr i-b mr-2']/div[2]"):
        price7.append(m.text)
except NoSuchElementException:
    price7.append("--")
except StaleElementReferenceException:
    price7.append("--")
except:
    price7.append("--")
try:
    for n in driver.find_elements_by_xpath("//div/div[1]/div[2]/div/div/div/div/div[1]/div/div[1]/p"):
        source7.append(n.text)
except NoSuchElementException:
    source7.append("--")
except StaleElementReferenceException:
    source7.append("--")
except:
    source7.append("--")
try:
    for o in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]"):
        destination7.append(o.text)
except NoSuchElementException:
    destination7.append("--")
except StaleElementReferenceException:
    destination7.append("--")
except:
    destination7.append("--")
try:
    for p in driver.find_elements_by_xpath("//span[@class='cursor-default']|//span[@class='dotted-borderbtm']"):
        stops7.append(p.text)
except NoSuchElementException:
    stops7.append("--")
except StaleElementReferenceException:
     stops7.append("--")
except:
     stops7.append("--")

    
for r in driver.find_elements_by_xpath("//div[@class='bold fs-12 mb-5']"):
    date7.append(r.text)

# %%
url="https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=CCU&originCountry=IN&destination=PNQ&destinationCountry=IN&flight_depart_date=01%2F04%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=1297890234836"
driver.get(url)

# %%
airline8=[]
source8=[]
destination8=[]
price8=[]
stops8=[]
Dep_time8=[]
arr_time8=[]
date8=[]
duration8=[]


try:
    for i in driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span"):
        airline8.append(i.text)
except NoSuchElementexception:
    airline8.append("--")
except StaleElementReferenceException:
    airline8.append("--")
except:
    airline8.append("--")
try:
    for j in driver.find_elements_by_xpath("//div[@class='i-b pr']"):
        Dep_time8.append(j.text)
except NoSuchElementException:
    Dep_time8.append("--")
except StaleElementReferenceException:
    Dep_time8.append("--")
except:
    Dep_time8.append("--")
try:
    for k in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[1]"):
        arr_time8.append(k.text)
except NoSuchElementException:
    arr_time8.append("--")
except StaleElementReferenceException:
    arr_time8.append("--")
except:
    arr_time8.append("--")
try:
    for l in driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/p"):
        duration8.append(l.text)
except NoSuchElementException:
    duration8.append("--")
except StaleElementReferenceException:
    duration8.append("--")
except:
    duration8.append("--")
try:
    for m in driver.find_elements_by_xpath("//div[@class='pr i-b mr-2']/div[2]"):
        price8.append(m.text)
except NoSuchElementException:
    price8.append("--")
except StaleElementReferenceException:
    price8.append("--")
except:
    price8.append("--")
try:
    for n in driver.find_elements_by_xpath("//div/div[1]/div[2]/div/div/div/div/div[1]/div/div[1]/p"):
        source8.append(n.text)
except NoSuchElementException:
    source8.append("--")
except StaleElementReferenceException:
    source8.append("--")
except:
    source8.append("--")
try:
    for o in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]"):
        destination8.append(o.text)
except NoSuchElementException:
    destination8.append("--")
except StaleElementReferenceException:
    destination8.append("--")
except:
    destination8.append("--")
try:
    for p in driver.find_elements_by_xpath("//span[@class='cursor-default']|//span[@class='dotted-borderbtm']"):
        stops8.append(p.text)
except NoSuchElementException:
    stops8.append("--")
except StaleElementReferenceException:
     stops8.append("--")
except:
     stops8.append("--")

    
for r in driver.find_elements_by_xpath("//div[@class='bold fs-12 mb-5']"):
    date8.append(r.text)

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=DEL&destinationCountry=IN&flexi=0&flight_depart_date=04%2F04%2F2022&hb=0&noOfSegments=1&origin=CCU&originCountry=IN&type=O&unique=689961780565&version=1.1&viewName=normal'
driver.get(url)

# %%
airline9=[]
source9=[]
destination9=[]
price9=[]
stops9=[]
Dep_time9=[]
arr_time9=[]
date9=[]
duration9=[]


try:
    for i in driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span"):
        airline9.append(i.text)
except NoSuchElementexception:
    airline9.append("--")
except StaleElementReferenceException:
    airline9.append("--")
except:
    airline9.append("--")
try:
    for j in driver.find_elements_by_xpath("//div[@class='i-b pr']"):
        Dep_time9.append(j.text)
except NoSuchElementException:
    Dep_time9.append("--")
except StaleElementReferenceException:
    Dep_time9.append("--")
except:
    Dep_time9.append("--")
try:
    for k in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[1]"):
        arr_time9.append(k.text)
except NoSuchElementException:
    arr_time9.append("--")
except StaleElementReferenceException:
    arr_time9.append("--")
except:
    arr_time9.append("--")
try:
    for l in driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/p"):
        duration9.append(l.text)
except NoSuchElementException:
    duration9.append("--")
except StaleElementReferenceException:
    duration9.append("--")
except:
    duration9.append("--")
try:
    for m in driver.find_elements_by_xpath("//div[@class='pr i-b mr-2']/div[2]"):
        price9.append(m.text)
except NoSuchElementException:
    price9.append("--")
except StaleElementReferenceException:
    price9.append("--")
except:
    price9.append("--")
try:
    for n in driver.find_elements_by_xpath("//div/div[1]/div[2]/div/div/div/div/div[1]/div/div[1]/p"):
        source9.append(n.text)
except NoSuchElementException:
    source9.append("--")
except StaleElementReferenceException:
    source9.append("--")
except:
    source9.append("--")
try:
    for o in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]"):
        destination9.append(o.text)
except NoSuchElementException:
    destination9.append("--")
except StaleElementReferenceException:
    destination9.append("--")
except:
    destination9.append("--")
try:
    for p in driver.find_elements_by_xpath("//span[@class='cursor-default']|//span[@class='dotted-borderbtm']"):
        stops9.append(p.text)
except NoSuchElementException:
    stops9.append("--")
except StaleElementReferenceException:
     stops9.append("--")
except:
     stops9.append("--")

    
for r in driver.find_elements_by_xpath("//div[@class='bold fs-12 mb-5']"):
    date9.append(r.text)

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=BLR&destinationCountry=IN&flexi=0&flight_depart_date=01%2F04%2F2022&hb=0&noOfSegments=1&origin=CCU&originCountry=IN&type=O&unique=1361273561002&version=1.1&viewName=normal'
driver.get(url)

# %%
airline10=[]
source10=[]
destination10=[]
price10=[]
stops10=[]
Dep_time10=[]
arr_time10=[]
date10=[]
duration10=[]


try:
    for i in driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span"):
        airline10.append(i.text)
except NoSuchElementexception:
    airline10.append("--")
except StaleElementReferenceException:
    airline10.append("--")
except:
    airline10.append("--")
try:
    for j in driver.find_elements_by_xpath("//div[@class='i-b pr']"):
        Dep_time10.append(j.text)
except NoSuchElementException:
    Dep_time10.append("--")
except StaleElementReferenceException:
    Dep_time10.append("--")
except:
    Dep_time10.append("--")
try:
    for k in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[1]"):
        arr_time10.append(k.text)
except NoSuchElementException:
    arr_time10.append("--")
except StaleElementReferenceException:
    arr_time10.append("--")
except:
    arr_time10.append("--")
try:
    for l in driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/p"):
        duration10.append(l.text)
except NoSuchElementException:
    duration10.append("--")
except StaleElementReferenceException:
    duration10.append("--")
except:
    duration10.append("--")
try:
    for m in driver.find_elements_by_xpath("//div[@class='pr i-b mr-2']/div[2]"):
        price10.append(m.text)
except NoSuchElementException:
    price10.append("--")
except StaleElementReferenceException:
    price10.append("--")
except:
    price10.append("--")
try:
    for n in driver.find_elements_by_xpath("//div/div[1]/div[2]/div/div/div/div/div[1]/div/div[1]/p"):
        source10.append(n.text)
except NoSuchElementException:
    source10.append("--")
except StaleElementReferenceException:
    source10.append("--")
except:
    source10.append("--")
try:
    for o in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]"):
        destination10.append(o.text)
except NoSuchElementException:
    destination10.append("--")
except StaleElementReferenceException:
    destination10.append("--")
except:
    destination10.append("--")
try:
    for p in driver.find_elements_by_xpath("//span[@class='cursor-default']|//span[@class='dotted-borderbtm']"):
        stops10.append(p.text)
except NoSuchElementException:
    stops10.append("--")
except StaleElementReferenceException:
     stops10.append("--")
except:
     stops10.append("--")

    
for r in driver.find_elements_by_xpath("//div[@class='bold fs-12 mb-5']"):
    date10.append(r.text)

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=HYD&destinationCountry=IN&flexi=0&flight_depart_date=02%2F04%2F2022&hb=0&noOfSegments=1&origin=CCU&originCountry=IN&type=O&unique=1112047717593&version=1.1&viewName=normal'
driver.get(url)

# %%
airline11=[]
source11=[]
destination11=[]
price11=[]
stops11=[]
Dep_time11=[]
arr_time11=[]
date11=[]
duration11=[]


try:
    for i in driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span"):
        airline11.append(i.text)
except NoSuchElementexception:
    airline11.append("--")
except StaleElementReferenceException:
    airline11.append("--")
except:
    airline11.append("--")
try:
    for j in driver.find_elements_by_xpath("//div[@class='i-b pr']"):
        Dep_time11.append(j.text)
except NoSuchElementException:
    Dep_time11.append("--")
except StaleElementReferenceException:
    Dep_time11.append("--")
except:
    Dep_time11.append("--")
try:
    for k in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[1]"):
        arr_time11.append(k.text)
except NoSuchElementException:
    arr_time11.append("--")
except StaleElementReferenceException:
    arr_time11.append("--")
except:
    arr_time11.append("--")
try:
    for l in driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/p"):
        duration11.append(l.text)
except NoSuchElementException:
    duration11.append("--")
except StaleElementReferenceException:
    duration11.append("--")
except:
    duration11.append("--")
try:
    for m in driver.find_elements_by_xpath("//div[@class='pr i-b mr-2']/div[2]"):
        price11.append(m.text)
except NoSuchElementException:
    price11.append("--")
except StaleElementReferenceException:
    price11.append("--")
except:
    price11.append("--")
try:
    for n in driver.find_elements_by_xpath("//div/div[1]/div[2]/div/div/div/div/div[1]/div/div[1]/p"):
        source11.append(n.text)
except NoSuchElementException:
    source11.append("--")
except StaleElementReferenceException:
    source11.append("--")
except:
    source11.append("--")
try:
    for o in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]"):
        destination11.append(o.text)
except NoSuchElementException:
    destination11.append("--")
except StaleElementReferenceException:
    destination11.append("--")
except:
    destination11.append("--")
try:
    for p in driver.find_elements_by_xpath("//span[@class='cursor-default']|//span[@class='dotted-borderbtm']"):
        stops11.append(p.text)
except NoSuchElementException:
    stops11.append("--")
except StaleElementReferenceException:
     stops11.append("--")
except:
     stops11.append("--")

    
for r in driver.find_elements_by_xpath("//div[@class='bold fs-12 mb-5']"):
    date11.append(r.text)

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?ADT=1&CHD=0&INF=0&class=Economy&destination=CCU&destinationCountry=IN&flexi=0&flight_depart_date=03%2F04%2F2022&hb=0&noOfSegments=1&origin=BOM&originCountry=IN&type=O&unique=1335960917956&version=1.1&viewName=normal'
driver.get(url)

# %%
airline12=[]
source12=[]
destination12=[]
price12=[]
stops12=[]
Dep_time12=[]
arr_time12=[]
date12=[]
duration12=[]


try:
    for i in driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span"):
        airline12.append(i.text)
except NoSuchElementexception:
    airline12.append("--")
except StaleElementReferenceException:
    airline12.append("--")
except:
    airline12.append("--")
try:
    for j in driver.find_elements_by_xpath("//div[@class='i-b pr']"):
        Dep_time12.append(j.text)
except NoSuchElementException:
    Dep_time12.append("--")
except StaleElementReferenceException:
    Dep_time12.append("--")
except:
    Dep_time12.append("--")
try:
    for k in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[1]"):
        arr_time12.append(k.text)
except NoSuchElementException:
    arr_time12.append("--")
except StaleElementReferenceException:
    arr_time12.append("--")
except:
    arr_time12.append("--")
try:
    for l in driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/p"):
        duration12.append(l.text)
except NoSuchElementException:
    duration12.append("--")
except StaleElementReferenceException:
    duration12.append("--")
except:
    duration12.append("--")
try:
    for m in driver.find_elements_by_xpath("//div[@class='pr i-b mr-2']/div[2]"):
        price12.append(m.text)
except NoSuchElementException:
    price12.append("--")
except StaleElementReferenceException:
    price12.append("--")
except:
    price12.append("--")
try:
    for n in driver.find_elements_by_xpath("//div/div[1]/div[2]/div/div/div/div/div[1]/div/div[1]/p"):
        source12.append(n.text)
except NoSuchElementException:
    source12.append("--")
except StaleElementReferenceException:
    source12.append("--")
except:
    source12.append("--")
try:
    for o in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]"):
        destination12.append(o.text)
except NoSuchElementException:
    destination12.append("--")
except StaleElementReferenceException:
    destination12.append("--")
except:
    destination12.append("--")
try:
    for p in driver.find_elements_by_xpath("//span[@class='cursor-default']|//span[@class='dotted-borderbtm']"):
        stops12.append(p.text)
except NoSuchElementException:
    stops12.append("--")
except StaleElementReferenceException:
     stops12.append("--")
except:
     stops12.append("--")

    
for r in driver.find_elements_by_xpath("//div[@class='bold fs-12 mb-5']"):
    date12.append(r.text)

# %%
url='https://flight.yatra.com/air-search-ui/dom2/trigger?type=O&viewName=normal&flexi=0&noOfSegments=1&origin=CCU&originCountry=IN&destination=GOI&destinationCountry=IN&flight_depart_date=02%2F04%2F2022&ADT=1&CHD=0&INF=0&class=Economy&source=fresco-home&unqvaldesktop=934193270374'
driver.get(url)

# %%
airline13=[]
source13=[]
destination13=[]
price13=[]
stops13=[]
Dep_time13=[]
arr_time13=[]
date13=[]
duration13=[]


try:
    for i in driver.find_elements_by_xpath("//div[@class='fs-13 airline-name no-pad col-8']/span"):
        airline13.append(i.text)
except NoSuchElementexception:
    airline13.append("--")
except StaleElementReferenceException:
    airline13.append("--")
except:
    airline13.append("--")
try:
    for j in driver.find_elements_by_xpath("//div[@class='i-b pr']"):
        Dep_time13.append(j.text)
except NoSuchElementException:
    Dep_time13.append("--")
except StaleElementReferenceException:
    Dep_time13.append("--")
except:
    Dep_time13.append("--")
try:
    for k in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[1]"):
        arr_time13.append(k.text)
except NoSuchElementException:
    arr_time13.append("--")
except StaleElementReferenceException:
    arr_time13.append("--")
except:
    arr_time13.append("--")
try:
    for l in driver.find_elements_by_xpath("//div[@class='stop-cont pl-13']/p"):
        duration13.append(l.text)
except NoSuchElementException:
    duration13.append("--")
except StaleElementReferenceException:
    duration13.append("--")
except:
    duration13.append("--")
try:
    for m in driver.find_elements_by_xpath("//div[@class='pr i-b mr-2']/div[2]"):
        price13.append(m.text)
except NoSuchElementException:
    price13.append("--")
except StaleElementReferenceException:
    price13.append("--")
except:
    price13.append("--")
try:
    for n in driver.find_elements_by_xpath("//div/div[1]/div[2]/div/div/div/div/div[1]/div/div[1]/p"):
        source13.append(n.text)
except NoSuchElementException:
    source13.append("--")
except StaleElementReferenceException:
    source13.append("--")
except:
    source13.append("--")
try:
    for o in driver.find_elements_by_xpath("//div[@class='i-b pdd-0 text-left atime col-5']/p[2]"):
        destination13.append(o.text)
except NoSuchElementException:
    destination13.append("--")
except StaleElementReferenceException:
    destination13.append("--")
except:
    destination13.append("--")
try:
    for p in driver.find_elements_by_xpath("//span[@class='cursor-default']|//span[@class='dotted-borderbtm']"):
        stops13.append(p.text)
except NoSuchElementException:
    stops13.append("--")
except StaleElementReferenceException:
     stops13.append("--")
except:
     stops13.append("--")

    
for r in driver.find_elements_by_xpath("//div[@class='bold fs-12 mb-5']"):
    date13.append(r.text)

# %%
air=(airline1+airline2+airline3+airline4+airline5+airline6+airline7+airline8+airline9+airline10+airline11+airline12+airline13)
sour=(source1+source2+source3+source4+source5+source6+source7+source8+source9+source10+source11+source12+source13)
dest=(destination1+destination2+destination3+destination4+destination5+destination6+destination7+destination8+destination9+destination10+destination11+destination12+destination13)
pri=(price1+price2+price3+price4+price5+price6+price7+price8+price9+price10+price11+price12+price13)
stop=(stops1+stops2+stops3+stops4+stops5+stops6+stops7+stops8+stops9+stops10+stops11+stops12+stops13)
Dep=(Dep_time1+Dep_time2+Dep_time3+Dep_time4+Dep_time5+Dep_time6+Dep_time7+Dep_time8+Dep_time9+Dep_time10+Dep_time11+Dep_time12+Dep_time13)
arr=(arr_time1+arr_time2+arr_time3+arr_time4+arr_time5+arr_time6+arr_time7+arr_time8+arr_time9+arr_time10+arr_time11+arr_time12+arr_time13)
dur=(duration1+duration2+duration3+duration4+duration5+duration6+duration6+duration7+duration8+duration9+duration10+duration11+duration12+duration13)
date=(date1+date2+date3+date4+date5+date6+date7+date8+date9+date10+date11+date12+date13)

# %%
Flight_price=pd.DataFrame({})
Flight_price['Airline']=air
Flight_price['Date']=Date
Flight_price['Source']=sour
Flight_price['Destination']=dest
Flight_price['Stops']=stop
Flight_price['Arrival_Time']=arr
Flight_price['Dep_Time']=Dep
Flight_price['Duration']=dur
Flight_price['Price']=pri
Flight_price['Add_info']=Add_info

# %%
Flight_price.to_csv("Flight_price_csv.csv")

# %%
pd.read_csv("Flight_price_csv.csv")
# Out:
#       Unnamed: 0    Airline              Date     Source Destination  \
# 0              0  Air India  Tue, 23 Nov 2021  Bangalore   New Delhi
# 1              1  Air India  Tue, 23 Nov 2021  Bangalore   New Delhi
# 2              2     IndiGo  Tue, 23 Nov 2021  Bangalore   New Delhi
# 3              3     IndiGo  Tue, 23 Nov 2021  Bangalore   New Delhi
# 4              4     IndiGo  Tue, 23 Nov 2021  Bangalore   New Delhi
# ...          ...        ...               ...        ...         ...
# 2192        2192    Vistara   Sat, 6 Nov 2021    Chennai        Pune
# 2193        2193    Vistara   Sat, 6 Nov 2021    Chennai        Pune
# 2194        2194  Air India   Sat, 6 Nov 2021    Chennai        Pune
# 2195        2195  Air India   Sat, 6 Nov 2021    Chennai        Pune
# 2196        2196  Air India   Sat, 6 Nov 2021    Chennai        Pune
#
#           Stops Arrival_Time Dep_Time Duration      Add_info   Price
# 0      Non Stop        20:20    17:20   3h 00m     Free Meal   3,234
# 1      Non Stop        08:45    05:45   3h 00m     Free Meal   3,546
# 2        1 Stop        23:45    18:45   5h 00m  No Meal Fare   3,546
# 3        1 Stop        18:10    13:05   5h 05m  No Meal Fare   3,546
# 4        1 Stop        20:25    15:20   5h 05m  No Meal Fare   3,546
# ...         ...          ...      ...      ...           ...     ...
# 2192  2 Stop(s)        18:35    07:00  11h 35m  No Meal Fare  20,163
# 2193  2 Stop(s)        18:35    07:00  11h 35m  No Meal Fare  20,163
# 2194  2 Stop(s)        18:10    08:30   9h 40m  No Meal Fare  21,528
# 2195  2 Stop(s)        18:10    06:20  11h 50m  No Meal Fare  22,788
# 2196  2 Stop(s)        18:10    05:55  12h 15m     Free Meal  37,531
#
# [2197 rows x 11 columns]
